# %%
from data_toolbox import *
from class_rates import *
from class_options import *
options = SPX_Options()

# %%
options.info

# %%
options.options_data

# %%
options.rate_curve.yield_curve

# %%
options.rate_curve.dt_yield_curve

# %%
options.clean_data.dropna()
# Out:
#                  as_of_date  time_to_maturity  risk_free_rate  \
# Expiration Date
# 2024-02-14       2024-02-13          0.002738        0.053100
# 2024-02-14       2024-02-13          0.002738        0.053100
# 2024-02-14       2024-02-13          0.002738        0.053100
# 2024-02-14       2024-02-13          0.002738        0.053100
# 2024-02-14       2024-02-13          0.002738        0.053100
# ...                     ...               ...             ...
# 2029-12-21       2024-02-13          5.855236        0.042999
# 2029-12-21       2024-02-13          5.855236        0.042999
# 2029-12-21       2024-02-13          5.855236        0.042999
# 2029-12-21       2024-02-13          5.855236        0.042999
# 2029-12-21       2024-02-13          5.855236        0.042999
#
#                                Calls  Implied_Vol     Mid  Strike  \
# Expiration Date
# 2024-02-14       SPXW240214C05000000     0.061285   23.15    5000
# ...

# %%
# Calls cleaned data
options.clean_data[['as_of_date', 'time_to_maturity', 'risk_free_rate','Implied_Vol','Mid', 'Strike']].dropna()

# %%
# Puts cleaned data
options.clean_data[['as_of_date', 'time_to_maturity', 'risk_free_rate','Implied_Vol.1','Mid.1', 'Strike']].dropna()
# Out:
#                  as_of_date  time_to_maturity  risk_free_rate  Implied_Vol.1  \
# Expiration Date
# 2024-02-14       2024-02-13          0.002738        0.053100       4.817695
# 2024-02-14       2024-02-13          0.002738        0.053100       4.335334
# 2024-02-14       2024-02-13          0.002738        0.053100       3.894706
# 2024-02-14       2024-02-13          0.002738        0.053100       3.488859
# 2024-02-14       2024-02-13          0.002738        0.053100       3.112388
# ...                     ...               ...             ...            ...
# 2029-12-21       2024-02-13          5.855236        0.042999       0.211450
# 2029-12-21       2024-02-13          5.855236        0.042999       0.211394
# 2029-12-21       2024-02-13          5.855236        0.042999       0.211789
# 2029-12-21       2024-02-13          5.855236        0.042999       0.212664
# 2029-12-21       2024-02-13          5.855236        0.042999       0.213977
#
# ...
